# %% [markdown]
# # MP3

# %% [markdown]
# ### L08 M1

# %% [markdown]
# ##### Region
# X = -0.7530, -0.7490
# Y = 0.0990, 0.1030

# %% [markdown]
# ##### τ
# 0.01

# %% [markdown]
# ##### Observation
# * Visually, less than 5% of pixels diverge before max iter, primarily concentrated at the fractal boundary
# * Trajectories diverge latest in the outer area of the fractal structure, where escape happens quickly and rounding errors have less time to accumulate.
# * High escape iteration counts correlate directly with early divergence. The more iterations a point undergoes, the more floating-point rounding errors compound

# %% [markdown]
# ### L08 M2

# %% [markdown]
# ##### Observation
# * $\kappa$ is largest along the boundary of the fractal structure, matching the edges in M1 very closely.
# * $\kappa$ for interior pixels is 0.00, as these points are stable and do not escape

# %% [markdown]
# ##### Comparions
# Both maps show the same underlying fractal structure, but highlight different properties.
# * M1: Shows the "speed" of divergence
# * M2: Acts like a stability probe. It reveals where the math is fundamentally unreliable due to the high sensitivity of the fractal's edge.

# %% [markdown]
# ### L09 M1
