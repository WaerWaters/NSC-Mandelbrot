# %% [markdown]
# # MP3

# %% [markdown]
# ### L08 M1

# %% [markdown]
# ##### Region
# X = -0.7530, -0.7490
# Y = 0.0990, 0.1030

# %% [markdown]
# ##### τ
# 0.01

# %% [markdown]
# ##### Observation
# * Visually, less than 5% of pixels diverge before max iter
# * Trajectories diverge early in the outer area of the fractal structure
# * No high escape iteration counts does not correlate with early divergence. A low escape iteration counts would lead to early divergence

# %% [markdown]
# ### L08 M2

# %% [markdown]
# ##### Observation
# * k is largest on the bottom right side of the plot. and it matches the boundary from M1 very closely
# * k for interior pixels are 0.00

# %% [markdown]
# ##### Comparions
# Both maps show the same underlying fractal structure, but highlight different properties.
# * M1: Shows a gradient that shows the speed of divergence
# * M2: Acts like a edge detector. it shows where the results are most likely to be unreliable

# %% [markdown]
# ### L09 M1
